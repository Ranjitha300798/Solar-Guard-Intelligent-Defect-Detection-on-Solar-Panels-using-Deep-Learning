jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/train/class4/Electrical (38).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/train/class4/Electrical (32).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/train/class4/Electrical (36).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/train/class4/Electrical (65).JPG (deflated 11%)
# updating: content/drive/MyDrive/dataset/train/class4/Electrical (53).JPG (deflated 6%)
# ...
# updating: content/drive/MyDrive/dataset/val/class3/Dust (137).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (146).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (171).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (145).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (151).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (165).jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (183).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (149).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (135).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (169).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (158).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (153).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (140).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (155).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (163).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (187).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (148).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (150).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (147).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (162).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (186).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (184).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (174).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (179).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (161).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (177).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (141).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (182).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (136).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (188).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (138).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (152).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (166).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (156).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (160).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (173).jpg (deflated 3%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (143).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (159).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (176).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (139).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (185).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (189).jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (167).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (144).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (178).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (170).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class3/Dust (175).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/ (stored 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (61).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (62).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (53).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (57).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (63).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (66).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (65).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (52).JPG (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (64).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (56).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (54).jpg (deflated 9%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (60).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (59).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (68).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (69).jpg (deflated 20%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (58).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (55).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class5/Physical (67).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/ (stored 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (166).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (172).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (187).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (181).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (147).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (184).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (144).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (192).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (158).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (173).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (161).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (148).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (182).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (151).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (193).png (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (153).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (141).JPG (deflated 4%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (183).jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (177).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (170).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (190).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (167).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (160).jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (180).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (149).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (186).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (169).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (176).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (171).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (154).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (142).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (165).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (159).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (185).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (174).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (163).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (146).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (155).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (157).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (156).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (189).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (164).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (178).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (191).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (145).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (175).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (188).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (150).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (168).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (162).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (152).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (143).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class2/Clean (179).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/ (stored 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (179).JPG (deflated 7%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (183).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (160).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (164).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (170).JPG (deflated 10%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (174).jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (198).JPG (deflated 8%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (165).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (168).jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (149).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (171).JPG (deflated 6%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (182).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (173).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (161).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (166).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (181).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (159).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (150).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (175).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (185).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (186).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (162).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (180).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (167).JPG (deflated 11%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (184).jpg (deflated 10%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (148).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (178).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (177).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (169).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (172).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (176).jpg (deflated 10%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (163).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (187).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (196).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (191).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (194).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (192).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (195).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (188).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (189).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (197).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (193).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class1/Bird (190).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/ (stored 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (113).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (101).jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (112).jpg (deflated 4%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (102).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (98).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (99).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (114).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (110).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (123).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (120).jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (93).JPG (deflated 8%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (108).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (97).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (91).JPG (deflated 15%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (115).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (103).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (95).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (111).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (96).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (104).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (94).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (107).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (119).jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (109).jpg (deflated 1%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (105).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (122).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (100).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (116).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (92).JPG (deflated 11%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (118).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (117).jpg (deflated 0%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (121).jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/val/class6/Snow (106).jpg (deflated 2%)
# updating: content/drive/MyDrive/dataset/val.zip (stored 0%)

# %%
# Path to your .zip file in Google Drive
zip_path = "/content/drive/MyDrive/dataset.zip"

# Folder to extract to
extract_path = "/content/dataset"

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Unzipped to:", extract_path)
# Out:
# ✅ Unzipped to: /content/dataset

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
data_dir = '/content/dataset/content/drive/MyDrive/dataset'

# Create data loaders
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
#image_datasets

# %%
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4, shuffle=True, num_workers=4) for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
print(dataset_sizes)

class_names = image_datasets['train'].classes
class_names
# Out:
# {'train': 634, 'val': 235}
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ['class1', 'class2', 'class3', 'class4', 'class5', 'class6']

# %%
model = models.resnet18(pretrained=True)

# Modify the final fully connected layer (assuming 6 classes)
num_classes = 6
model.fc = nn.Linear(model.fc.in_features, num_classes)

# Unfreeze the last block (layer4) and the final fc layer
for name, param in model.named_parameters():
    if "layer4" in name or "fc" in name:
        param.requires_grad = True
    else:
        param.requires_grad = False

# Define loss function
criterion = nn.CrossEntropyLoss()

# Use Adam optimizer with a smaller learning rate
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

# Optional: Learning rate scheduler (decays LR every 5 epochs)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# Move the model to the GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 112MB/s]

# %%
import copy
import time

best_model_wts = copy.deepcopy(model.state_dict())
best_acc = 0.0
since = time.time()

num_epochs = 10
for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    print('-' * 30)

    for phase in ['train', 'val']:
        if phase == 'train':
            model.train()
        else:
            model.eval()

        running_loss = 0.0
        running_corrects = 0

        for inputs, labels in dataloaders[phase]:
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    loss.backward()
                    optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        if phase == 'train':
            scheduler.step()

        epoch_loss = running_loss / dataset_sizes[phase]
        epoch_acc = running_corrects.double() / dataset_sizes[phase]

        print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} | Acc: {epoch_acc:.4f}')

        # Deep copy best model
        if phase == 'val' and epoch_acc > best_acc:
            best_acc = epoch_acc
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), 'best_model.pth')
            print("✅ Best model updated and saved.")

time_elapsed = time.time() - since
print(f"\nTraining complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s")
print(f"Best Validation Accuracy: {best_acc:.4f}")

# Load best weights
model.load_state_dict(best_model_wts)
# Out:
# Epoch 1/10
# ------------------------------
# Train Loss: 1.1473 | Acc: 0.5710
# Val Loss: 0.6905 | Acc: 0.7489
# ✅ Best model updated and saved.
#
# Epoch 2/10
# ------------------------------
# Train Loss: 0.8701 | Acc: 0.6924
# Val Loss: 0.5562 | Acc: 0.8085
# ✅ Best model updated and saved.
#
# Epoch 3/10
# ------------------------------
# Train Loss: 0.7948 | Acc: 0.7192
# Val Loss: 0.5292 | Acc: 0.8426
# ✅ Best model updated and saved.
#
# Epoch 4/10
# ------------------------------
# Train Loss: 0.7064 | Acc: 0.7603
# Val Loss: 0.5260 | Acc: 0.8638
# ✅ Best model updated and saved.
#
# Epoch 5/10
# ------------------------------
# Train Loss: 0.6596 | Acc: 0.7618
# Val Loss: 0.6298 | Acc: 0.8128
#
# Epoch 6/10
# ------------------------------
# Train Loss: 0.6044 | Acc: 0.7792
# Val Loss: 0.5586 | Acc: 0.8553
#
# Epoch 7/10
# ------------------------------
# Train Loss: 0.5222 | Acc: 0.8060
# Val Loss: 0.5287 | Acc: 0.8638
#
# Epoch 8/10
# ------------------------------
# Train Loss: 0.5476 | Acc: 0.8218
# Val Loss: 0.5290 | Acc: 0.8468
#
# Epoch 9/10
# ------------------------------
# Train Loss: 0.4940 | Acc: 0.8375
# Val Loss: 0.5383 | Acc: 0.8766
# ✅ Best model updated and saved.
#
# Epoch 10/10
# ------------------------------
# Train Loss: 0.4682 | Acc: 0.8438
# Val Loss: 0.5294 | Acc: 0.8340
#
# Training complete in 3m 7s
# Best Validation Accuracy: 0.8766
# <All keys matched successfully>

# %%
# Save the model
torch.save(model.state_dict(), 'solarr_classification_model.pth')
